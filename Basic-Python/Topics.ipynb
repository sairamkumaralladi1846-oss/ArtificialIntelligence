# %%
# Def

# %% [markdown]
# - interpreted/compiled
# - portable(crossplatform)
# - Dynamical/static

# %%
.exec(windows),mac(.app)

# %% [markdown]
# - variables-
# - arithmatic
# - datatypes
# - controlflows(conditional operators)
# - functions
# - datastrucures
# - oops
# - file handling
# - exceptional handling
# - decorators
# - higher order func(map,filter,reduce)
# - generators
# - recursion
# - modules/packages
# - regex
# - name & __main__
# - multithreading
